# %% [markdown]
# # Visualization in Data Science

# %% [markdown]
# #### Here in data science visualization is needed to show the data to clients
# #### This is a graphical representation of data in python

# %% [markdown]
# #### * Represetation Resources : Visualization with Pandas, Seaborn and Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
data = pd.read_csv('nba_logreg.csv')

# %%
data.head()
# Out:
#               Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0
#
#       ...       FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0     ...       2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3          0.0
# 1     ...       3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6          0.0
# 2     ...       1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0          0.0
# 3     ...       1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0          1.0
# 4     ...       1.9  67.4   1.0   1.5  2.5  0.3  0.3  0.4  0.8          1.0
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (1340, 21)

# %%
data.columns
# Out:
# Index(['Name', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3P Made', '3PA',
#        '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#        'TOV', 'TARGET_5Yrs'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 GP          MIN          PTS          FGM          FGA  \
# count  1340.000000  1340.000000  1340.000000  1340.000000  1340.000000
# mean     60.414179    17.624627     6.801493     2.629104     5.885299
# std      17.433992     8.307964     4.357545     1.683555     3.593488
# min      11.000000     3.100000     0.700000     0.300000     0.800000
# 25%      47.000000    10.875000     3.700000     1.400000     3.300000
# 50%      63.000000    16.100000     5.550000     2.100000     4.800000
# 75%      77.000000    22.900000     8.800000     3.400000     7.500000
# max      82.000000    40.900000    28.200000    10.200000    19.800000
#
#                FG%      3P Made          3PA          3P%          FTM  \
# count  1340.000000  1340.000000  1340.000000  1329.000000  1340.000000
# mean     44.169403     0.247612     0.779179    19.308126     1.297687
# std       6.137679     0.383688     1.061847    16.022916     0.987246
# ...

# %% [markdown]
# ## Basic Chart Types
#
# 1. Scatter Plots
# 2. Line Plots
# 3. Bar Plots
# 4. Histograms

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# ##### Now we will use matplotlib to plot the graph between 3P Made and FT%

# %%
plt.plot(data['3P Made'], data['FT%'], 'ro') # 'ro' represents scatter plot in matplotlib

# %% [markdown]
# ##### Here we will use pandas directly to plot the graph between 3P Made and FT%
#
# 1. The advantage of pandas to plot is we can name both x and y axis at a time as column names and plot also looks better

# %%
data.plot(kind = "Scatter", x = '3P Made', y = 'FT%')

# %% [markdown]
# The user can define his own axis by using the command: a = plt.figure(figsize=(x_co_ordinates,y_co_ordinates))
#
#                                                        fit = a.gca()
#
#                                                        data.plot(kind = "Scatter", x = "X_Column", y = "Y_Columns", ax=fit)

# %%
ax = plt.figure(figsize=(6,6))
ax = ax.gca()
data.plot(kind = "Scatter", x = "3P Made", y = "FT%", ax=ax) # Here ax = ax represents to draw scatter in the block we created. 
plt.title("Sample Graph Scatter Plot")
# Out:
# Text(0.5,1,'Sample Graph Scatter Plot')

# %% [markdown]
# # Line Plots

# %% [markdown]
# Line plot is a default plot in both matplotlib and as well as in pandas

# %%
fig  = plt.figure(figsize=(8,8))
ax = fig.gca()
plt.plot(data['3P Made'],data['FT%'])
plt.title("Sample plot for line plot")
# Out:
# Text(0.5,1,'Sample plot for line plot')

# %% [markdown]
# Plotting using pandas

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.gca()
data.plot(kind = "Line", x = "3P Made", y = "FT%", ax = ax)
plt.title("Sample plot of line plot using pandas")
# Out:
# Text(0.5,1,'Sample plot of line plot using pandas')

# %% [markdown]
# # Using seaborn

# %% [markdown]
# 1. Import Seaborn Package
# 2. Set the stlye of grid
# 3. Define Plot type with kdeplot

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid") # one of most used styles in data science

# %%
sns.kdeplot(data['3P Made']) # This gives probability density curve

# %%
sns.kdeplot(data['FT%']) # This also gives probability density curve

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.gca()
sns.set_style("whitegrid")
sns.kdeplot(data["3P Made"], ax=ax)
plt.title("Sample Seaborn")
# Out:
# Text(0.5,1,'Sample Seaborn')

# %%
sns.set_style("darkgrid")
sns.sinplot(data["3P Made"], np.sin())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-9076a0fa6ea2> in <module>()
#       1 sns.set_style("darkgrid")
# ----> 2 sns.sinplot(data["3P Made"], ax=ax)
#
# AttributeError: module 'seaborn' has no attribute 'sinplot'
